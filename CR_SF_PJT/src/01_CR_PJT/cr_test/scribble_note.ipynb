# %%
import numpy as np

a = np.array([[0.95, 1.1], [1, 1]])
b = np.array([284, 280])
x = np.linalg.solve(a, b)
x1, y1 = 0.95*x[0], 1.1*x[1]
z = x1+ y1
print(x1, y1, z)
# Out:
# 152.0000000000001 131.99999999999991 284.0
